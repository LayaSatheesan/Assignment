# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read excel file from system

data_new=pd.read_excel("C:\\Users\\LAYA  S\\iris.xls")


#display the contents of dataset.It also display all the columns.

data_new
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Calculate the mean of each column of the dataset.
data_new.mean()
# Out:
# C:\Users\LAYA  S\AppData\Local\Temp\ipykernel_3456\2861894018.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_new.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#Check for the null values present in the dataset.
#It gives False as output.
#So there is no missing values.
data_new.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Create boxplot

# %%
plt.boxplot(data_new['SL'])
plt.show()

# %% [markdown]
# # Create Scatter plot

# %%
plt.scatter(data_new["SL"],data_new['PL'])
plt.title("Scatter plot between SL and PL")
plt.xlabel("SL")
plt.ylabel("PL")
plt.show()

# %% [markdown]
# # Histogram using matplotlib

# %%
plt.figure(figsize=(8,6))
plt.hist(data_new['SL'])
plt.title("SL")
plt.xlabel("SL")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Histogram using seaborn

# %%
plt.figure(figsize=(8,6))
sns.histplot(x=data_new['SL'])
plt.title("SL")
plt.show()

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data_new['SL'])
plt.ylabel("SL")
plt.show()

# %% [markdown]
# # Boxplot using seaborn

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=data_new['Classification'],y=data_new['PL'])
plt.title("Classification Vs PL")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Scatterplot

# %%
plt.scatter(data_new['SL'],data_new['SW'])
plt.title("SL Vs SW")
plt.xlabel("SL")
plt.ylabel("SW")
plt.show()

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x=data_new['Classification'],y=data_new['PL'])
plt.title("Classification Vs PL")
plt.show()

# %% [markdown]
# # Pairplot

# %%
data_2=data_new[['SL','PL','SW','PW']]
sns.pairplot(data_2)
plt.show()

# %%
sns.countplot(x=data_new['Classification'])
plt.xlabel("Classification")
plt.show()
